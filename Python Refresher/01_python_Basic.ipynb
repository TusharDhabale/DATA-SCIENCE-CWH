# %%
a = 5

# %%
b = 32

# %%
a + b
# Out:
# 37

# %%
name = "Tushar"

# %%
print("Hello World")
# Out:
# Hello World

# %%
## this is a comment

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
a = "324342"

# %%
b = "138324"

# %%
print(a+b)
# Out:
# 324342138324

# %%
int(a) + int (b) ## Type casting
# Out:
# 462666
