# %%
a = input("Enter the of a ") # By default it takes user inpute as string
# Out:
# Enter the of a  45

# %%
a
# Out:
# '45'

# %%
b = input("Enter the of b ")
# Out:
# Enter the of b  30

# %%
b
# Out:
# '30'

# %%
a + b
# Out:
# '4530'

# %%
int(a) + int(b)
# Out:
# 75

# %%
 c = input()
# Out:
#  50
